# %% [markdown]
# <a href="https://colab.research.google.com/github/Chirag230/Multithreading-matrix-multiplication/blob/main/Multithreading_Matrix_Multiplication_102103335.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time
import multiprocessing
import pandas as pd
import matplotlib.pyplot as plt
import psutil

# %%
# Function to perform matrix multiplication with a constant matrix
def matrix_multiply(constant_matrix, num_threads):
    # Generate random matrix of size 1000x1000
    random_matrix = np.random.rand(1000, 1000)
    # Start timing
    start_time = time.time()
    # Multiply random matrix with constant matrix using the specified number of threads
    np.dot(random_matrix, constant_matrix)
    # End timing
    end_time = time.time()
    # Calculate time taken
    time_taken = end_time - start_time
    cpu_usage = psutil.cpu_percent()
    print(f"CPU usage: {cpu_usage}%")
    return time_taken

# %%
# Generate constant matrix of size 1000x1000
constant_matrix = np.random.rand(1000, 1000)

# Define the number of threads
num_threads = [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Perform matrix multiplication with different number of threads
time_taken_list = []
for t in num_threads:
    time_taken = matrix_multiply(constant_matrix, t)
    time_taken_list.append(time_taken)

result_df = pd.DataFrame({'Threads': num_threads, 'Time Taken (Sec)': time_taken_list})
# Out:
# CPU usage: 54.6%
# CPU usage: 100.0%
# CPU usage: 100.0%
# CPU usage: 100.0%
# CPU usage: 100.0%
# CPU usage: 100.0%
# CPU usage: 100.0%
# CPU usage: 100.0%

# %%
# Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(num_threads, time_taken_list, marker='o')
plt.title('Matrix Multiplication Time vs. Number of Threads')
plt.xlabel('Number of Threads')
plt.ylabel('Time Taken (Seconds)')
plt.grid(True)
plt.show()

# %%
# Display the result table
print("\nResult Table:")
print(result_df)
# Out:
# Result Table:
#    Threads  Time Taken (Sec)
# 0        1          0.147262
# 1        2          0.116143
# 2        3          0.105724
# 3        4          0.120799
# 4        5          0.092993
# 5        6          0.104410
# 6        7          0.161584
# 7        8          0.130766
